# %%
import pandas as pd

# %%
# !pip install xlrd

# %%
# !pip install openpyxl
url = "https://www.sharkattackfile.net/spreadsheets/GSAF5.xls"
df = pd.read_excel(url)

# %%
df
# Out:
#                      Date    Year        Type             Country  \
# 0     2025-01-02 00:00:00  2025.0  Unprovoked       New Caledonia
# 1     2025-01-02 00:00:00  2025.0  Unprovoked           Australia
# 2     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# 3     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# 4     2024-12-28 00:00:00  2024.0  Unprovoked           Australia
# ...                   ...     ...         ...                 ...
# 6984          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6985          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6986            1900-1905     0.0  Unprovoked                 USA
# 6987            1883-1889     0.0  Unprovoked              PANAMA
# 6988            1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                     State                                 Location  \
# 0            Grande Terre              Islet of Kendek near Koumac
# ...

# %%
df.dtypes
# Out:
# Date               object
# Year              float64
# Type               object
# Country            object
# State              object
# Location           object
# Activity           object
# Name               object
# Sex                object
# Age                object
# Injury             object
# Fatal Y/N          object
# Time               object
# Species            object
# Source             object
# pdf                object
# href formula       object
# href               object
# Case Number        object
# Case Number.1      object
# original order    float64
# Unnamed: 21        object
# Unnamed: 22        object
# dtype: object

# %%
df.describe()
# Out:
#               Year  original order
# count  6987.000000     6799.000000
# mean   1934.979963     3401.152081
# std     272.134817     1963.076319
# min       0.000000        2.000000
# 25%    1947.000000     1701.500000
# 50%    1985.000000     3401.000000
# 75%    2009.000000     5100.500000
# max    2026.000000     6802.000000

# %%
df.nunique()
# Out:
# Date              6037
# Year               261
# Type                12
# Country            239
# State              920
# Location          4550
# Activity          1598
# Name              5723
# Sex                  8
# Age                246
# Injury            4118
# Fatal Y/N           12
# Time               431
# Species           1706
# Source            5344
# pdf               6789
# href formula      6784
# href              6776
# Case Number       6777
# Case Number.1     6775
# original order    6797
# Unnamed: 21          1
# Unnamed: 22          2
# dtype: int64

# %%
df.Type.unique()
# Out:
# array(['Unprovoked', ' Provoked', 'Provoked', 'Questionable',
#        'Watercraft', 'Sea Disaster', nan, '?', 'Unconfirmed',
#        'Unverified', 'Invalid', 'Under investigation', 'Boat'],
#       dtype=object)

# %%
df
# Out:
#                      Date    Year        Type             Country  \
# 0     2025-01-02 00:00:00  2025.0  Unprovoked       New Caledonia
# 1     2025-01-02 00:00:00  2025.0  Unprovoked           Australia
# 2     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# 3     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# 4     2024-12-28 00:00:00  2024.0  Unprovoked           Australia
# ...                   ...     ...         ...                 ...
# 6984          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6985          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6986            1900-1905     0.0  Unprovoked                 USA
# 6987            1883-1889     0.0  Unprovoked              PANAMA
# 6988            1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                     State                                 Location  \
# 0            Grande Terre              Islet of Kendek near Koumac
# ...

# %%
df[["Sex"]]
# Out:
#      Sex
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
# ...   ..
# 6984   M
# 6985   M
# 6986   M
# 6987   M
# 6988   M
#
# [6989 rows x 1 columns]

# %%
object_df = df.select_dtypes(include='object').describe()
object_df
# Out:
#         Date        Type Country    State                          Location  \
# count   6989        6971    6939     6507                              6424
# unique  6037          12     239      920                              4550
# top     1957  Unprovoked     USA  Florida  New Smyrna Beach, Volusia County
# freq       9        5151    2555     1185                               191
#
#        Activity  Name   Sex   Age Injury  ...       Time     Species   \
# count      6404  6770  6410  3995   6954  ...       3463         3857
# unique     1598  5723     8   246   4118  ...        431         1706
# top     Surfing  male     M    16  FATAL  ...  Afternoon  White shark
# freq       1131   680  5610    92    863  ...        215          194
#
#                                  Source                        pdf  \
# count                              6970                       6799
# unique                             5344                       6789
# ...

# %%
df[["Sex", "Country"]].value_counts()
# Out:
# Sex  Country
# M    USA                2026
#      AUSTRALIA          1222
#      SOUTH AFRICA        504
# F    USA                 421
#      AUSTRALIA           112
#                         ...
# M    Coast of AFRICA       1
#      Coral Sea             1
#      DIEGO GARCIA          1
#      EGYPT / ISRAEL        1
# lli  USA                   1
# Name: count, Length: 301, dtype: int64

# %%
df.keys()
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
unique_genders = df['Sex'].unique()

print(unique_genders)
# Out:
# ['M' 'F' nan ' M' 'M ' 'lli' 'M x 2' 'N' '.']

# %%
import pandas as pd

# Sample DataFrame
# Define the variations to be replaced with 'F'
female_variations = ['Femal', 'Female',' F','F ']

# Replace the variations with 'F'
df['Sex'] = df['Sex'].replace(female_variations, 'F')

print(df)
# Out:
#                      Date    Year        Type             Country  \
# 0     2025-01-02 00:00:00  2025.0  Unprovoked       New Caledonia
# 1     2025-01-02 00:00:00  2025.0  Unprovoked           Australia
# 2     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# 3     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# 4     2024-12-28 00:00:00  2024.0  Unprovoked           Australia
# ...                   ...     ...         ...                 ...
# 6984          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6985          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6986            1900-1905     0.0  Unprovoked                 USA
# 6987            1883-1889     0.0  Unprovoked              PANAMA
# 6988            1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                     State                                 Location  \
# 0            Grande Terre              Islet of Kendek near Koumac
# ...

# %%
df.head(10)
# Out:
#                   Date    Year        Type        Country  \
# 0  2025-01-02 00:00:00  2025.0  Unprovoked  New Caledonia
# 1  2025-01-02 00:00:00  2025.0  Unprovoked      Australia
# 2  2024-12-29 00:00:00  2024.0  Unprovoked          Egypt
# 3  2024-12-29 00:00:00  2024.0  Unprovoked          Egypt
# 4  2024-12-28 00:00:00  2024.0  Unprovoked      Australia
# 5  2024-12-02 00:00:00  2024.0  Unprovoked      Australia
# 6  2024-12-01 00:00:00  2024.0  Unprovoked      Australia
# 7  2024-11-30 00:00:00  2024.0  Unprovoked       Thailand
# 8  2024-11-19 00:00:00  2024.0  Unprovoked    New Zealand
# 9  2024-11-15 00:00:00  2024.0  Unprovoked       Maldives
#
#                  State                                           Location  \
# 0         Grande Terre                        Islet of Kendek near Koumac
# 1      South Australia            Granites Beach near Westall Streaky Bay
# 2  North of Marsa Alam                                            Red Sea
# ...

# %%
import pandas as pd

# Sample DataFrame
# Define the variations to be replaced with 'F'
male_variations = ['Male', 'male'' M','M ']

# Replace the variations with 'F'
df['Sex'] = df['Sex'].replace(male_variations, 'M')

print(df)
# Out:
#                      Date    Year        Type             Country  \
# 0     2025-01-02 00:00:00  2025.0  Unprovoked       New Caledonia
# 1     2025-01-02 00:00:00  2025.0  Unprovoked           Australia
# 2     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# 3     2024-12-29 00:00:00  2024.0  Unprovoked               Egypt
# 4     2024-12-28 00:00:00  2024.0  Unprovoked           Australia
# ...                   ...     ...         ...                 ...
# 6984          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6985          Before 1903     0.0  Unprovoked           AUSTRALIA
# 6986            1900-1905     0.0  Unprovoked                 USA
# 6987            1883-1889     0.0  Unprovoked              PANAMA
# 6988            1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                     State                                 Location  \
# 0            Grande Terre              Islet of Kendek near Koumac
# ...

# %%
df.head(10)
# Out:
#                   Date    Year        Type        Country  \
# 0  2025-01-02 00:00:00  2025.0  Unprovoked  New Caledonia
# 1  2025-01-02 00:00:00  2025.0  Unprovoked      Australia
# 2  2024-12-29 00:00:00  2024.0  Unprovoked          Egypt
# 3  2024-12-29 00:00:00  2024.0  Unprovoked          Egypt
# 4  2024-12-28 00:00:00  2024.0  Unprovoked      Australia
# 5  2024-12-02 00:00:00  2024.0  Unprovoked      Australia
# 6  2024-12-01 00:00:00  2024.0  Unprovoked      Australia
# 7  2024-11-30 00:00:00  2024.0  Unprovoked       Thailand
# 8  2024-11-19 00:00:00  2024.0  Unprovoked    New Zealand
# 9  2024-11-15 00:00:00  2024.0  Unprovoked       Maldives
#
#                  State                                           Location  \
# 0         Grande Terre                        Islet of Kendek near Koumac
# 1      South Australia            Granites Beach near Westall Streaky Bay
# 2  North of Marsa Alam                                            Red Sea
# ...
